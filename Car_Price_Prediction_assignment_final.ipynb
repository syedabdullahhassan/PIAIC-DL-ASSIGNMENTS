# %% [markdown]
# # Car Price Prediction::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/hellbuoy/car-price-prediction

# %% [markdown]
# # Problem Statement::

# %%
# mount google drive in to your Colab enviornment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/AI_assignment/
# Out:
# /content/drive/MyDrive/AI_assignment

# %% [markdown]
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car
# How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# # task::
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# # WORKFLOW ::

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 4.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 5.Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# 6.Train the Model with Epochs (100) and validate it
#
# 7.If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
#
# 8.Evaluation Step
#
# 9.Prediction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
car_data = pd.read_csv('/content/drive/MyDrive/PIAIC-DL-ASSIGNMENT/CarPrice_Assignment.csv')

# %%
import tensorflow as tf

# %%
car_data.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
car_data['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
#check if there are empty cells, if there are then row and column indexes will be returned where values are empty or missing
np.where(car_data.applymap(lambda x: x ==''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
car_data.isnull().any()
# Out:
# car_ID              False
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
# correct the name error in audi 100 ls
car_data.iloc[3,2] = 'audi 100ls'

# %%
car_data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
car_data.drop(columns=['car_ID'], inplace = True)

# %%
# get columns so that we can use the column names for onehot encoding of catagorical featrues in next cell
car_data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
# onehot encode all catagorical columns
final_car = pd.get_dummies(car_data, columns=['CarName','symboling','fueltype',	'aspiration',	'doornumber',	'carbody',	'drivewheel',	'enginelocation',	'enginetype',	'cylindernumber',	'fuelsystem'], drop_first = True)

# %%
final_car.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       88.6      168.8  ...                0                0
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
#
# [5 rows x 193 columns]

# %%
#check statistical data to see abnormal values and outliers
final_car.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  205.000000  205.000000  ...       205.000000       205.000000
# mean    98.756585  174.049268  ...         0.043902         0.004878
# std      6.021776   12.337289  ...         0.205380         0.069843
# min     86.600000  141.100000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     97.000000  173.200000  ...         0.000000         0.000000
# 75%    102.400000  183.100000  ...         0.000000         0.000000
# max    120.900000  208.100000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
#initialize a seed value so that each time we can get the same random number sequence, it will help us  as a team
# working on a common project to work on the same random data. Each new seed will generate a particular sequnce
#of random number. You can choose any seed value here of your choice
# 0.72 means we have taken 72% values for training set as we will make 72/4 = 18 rows of k fold validation data, where
# value of k will be 4 when we compile and fit our model for validation
np.random.seed(11111)
msk = np.random.rand(len(final_car)) < 0.72
train_total = final_car[msk]
test_total = final_car[~msk]

# %%
#check the length of our test and train datasets
print(len(train_total))
print(len(test_total))
# Out:
# 141
# 64

# %%
train_total.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1        88.6      168.8  ...                0                0
# 2        94.5      171.2  ...                0                0
# 3        99.8      176.6  ...                0                0
# 4        99.4      176.6  ...                0                0
# 5        99.8      177.3  ...                0                0
# 6       105.8      192.7  ...                0                0
# 7       105.8      192.7  ...                0                0
# 8       105.8      192.7  ...                0                0
# 9        99.5      178.2  ...                0                0
# 11      101.2      176.8  ...                0                0
#
# [10 rows x 193 columns]

# %%
# check statistical overview if there are some outliers and abnormal values
train_total.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  141.000000  141.000000  ...       141.000000       141.000000
# mean    98.692199  173.658156  ...         0.035461         0.007092
# std      6.005665   12.320089  ...         0.185601         0.084215
# min     86.600000  144.600000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     96.500000  172.400000  ...         0.000000         0.000000
# 75%    102.400000  180.300000  ...         0.000000         0.000000
# max    115.600000  202.600000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
print(train_total.dtypes)
# Out:
# wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
# curbweight           int64
#                     ...
# fuelsystem_idi       uint8
# fuelsystem_mfi       uint8
# fuelsystem_mpfi      uint8
# fuelsystem_spdi      uint8
# fuelsystem_spfi      uint8
# Length: 193, dtype: object

# %%
# get our price labels and store in another dataframe
train_label = train_total.loc[:,'price']
test_label = test_total.loc[:,'price']

# %%
train_label
# Out:
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 141, dtype: float64

# %%
# drop price from oroginal training and test dataset , as price is not needed there
test_data= test_total.drop(columns = ['price'])
train_data= train_total.drop(columns = ['price'])

# %%
train_data.shape
# Out:
# (141, 192)

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# 5         99.8      177.3  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [141 rows x 192 columns]

# %%
#get indices of the columns so that we can know how many columns we have to normalize, as catagorical columns which we
# have added with onehot encoding, do not need to be normalized.. normalizing will be done in next cell
{train_data.columns.get_loc(c): c for idx, c in enumerate(train_data.columns)}
# Out:
# {0: 'wheelbase',
#  1: 'carlength',
#  2: 'carwidth',
#  3: 'carheight',
#  4: 'curbweight',
#  5: 'enginesize',
#  6: 'boreratio',
#  7: 'stroke',
#  8: 'compressionratio',
#  9: 'horsepower',
#  10: 'peakrpm',
#  11: 'citympg',
#  12: 'highwaympg',
#  13: 'CarName_alfa-romero Quadrifoglio',
#  14: 'CarName_alfa-romero giulia',
#  15: 'CarName_alfa-romero stelvio',
#  16: 'CarName_audi 100ls',
#  17: 'CarName_audi 4000',
#  18: 'CarName_audi 5000',
#  19: 'CarName_audi 5000s (diesel)',
#  20: 'CarName_audi fox',
#  21: 'CarName_bmw 320i',
#  22: 'CarName_bmw x1',
#  23: 'CarName_bmw x3',
#  24: 'CarName_bmw x4',
#  25: 'CarName_bmw x5',
#  26: 'CarName_bmw z4',
#  27: 'CarName_buick century',
#  28: 'CarName_buick century luxus (sw)',
#  29: 'CarName_buick century special',
#  30: 'CarName_buick electra 225 custom',
#  31: 'CarName_buick opel isuzu deluxe',
#  32: 'CarName_buick regal sport coupe (turbo)',
#  33: 'CarName_buick skyhawk',
#  34: 'CarName_buick skylark',
#  35: 'CarName_chevrolet impala',
#  36: 'CarName_chevrolet monte carlo',
#  37: 'CarName_chevrolet vega 2300',
#  38: 'CarName_dodge challenger se',
#  39: 'CarName_dodge colt (sw)',
#  40: 'CarName_dodge colt hardtop',
#  41: 'CarName_dodge coronet custom',
#  42: 'CarName_dodge coronet custom (sw)',
#  43: 'CarName_dodge d200',
#  44: 'CarName_dodge dart custom',
#  45: 'CarName_dodge monaco (sw)',
#  46: 'CarName_dodge rampage',
#  47: 'CarName_honda accord',
#  48: 'CarName_honda accord cvcc',
#  49: 'CarName_honda accord lx',
#  50: 'CarName_honda civic',
#  51: 'CarName_honda civic (auto)',
#  52: 'CarName_honda civic 1300',
#  53: 'CarName_honda civic 1500 gl',
#  54: 'CarName_honda civic cvcc',
#  55: 'CarName_honda prelude',
#  56: 'CarName_isuzu D-Max ',
#  57: 'CarName_isuzu D-Max V-Cross',
#  58: 'CarName_isuzu MU-X',
#  59: 'CarName_jaguar xf',
#  60: 'CarName_jaguar xj',
#  61: 'CarName_jaguar xk',
#  62: 'CarName_maxda glc deluxe',
#  63: 'CarName_maxda rx3',
#  64: 'CarName_mazda 626',
#  65: 'CarName_mazda glc',
#  66: 'CarName_mazda glc 4',
#  67: 'CarName_mazda glc custom',
#  68: 'CarName_mazda glc custom l',
#  69: 'CarName_mazda glc deluxe',
#  70: 'CarName_mazda rx-4',
#  71: 'CarName_mazda rx-7 gs',
#  72: 'CarName_mazda rx2 coupe',
#  73: 'CarName_mercury cougar',
#  74: 'CarName_mitsubishi g4',
#  75: 'CarName_mitsubishi lancer',
#  76: 'CarName_mitsubishi mirage',
#  77: 'CarName_mitsubishi mirage g4',
#  78: 'CarName_mitsubishi montero',
#  79: 'CarName_mitsubishi outlander',
#  80: 'CarName_mitsubishi pajero',
#  81: 'CarName_nissan clipper',
#  82: 'CarName_nissan dayz',
#  83: 'CarName_nissan fuga',
#  84: 'CarName_nissan gt-r',
#  85: 'CarName_nissan juke',
#  86: 'CarName_nissan kicks',
#  87: 'CarName_nissan latio',
#  88: 'CarName_nissan leaf',
#  89: 'CarName_nissan note',
#  90: 'CarName_nissan nv200',
#  91: 'CarName_nissan otti',
#  92: 'CarName_nissan rogue',
#  93: 'CarName_nissan teana',
#  94: 'CarName_nissan titan',
#  95: 'CarName_peugeot 304',
#  96: 'CarName_peugeot 504',
#  97: 'CarName_peugeot 504 (sw)',
#  98: 'CarName_peugeot 505s turbo diesel',
#  99: 'CarName_peugeot 604sl',
#  100: 'CarName_plymouth cricket',
#  101: 'CarName_plymouth duster',
#  102: 'CarName_plymouth fury gran sedan',
#  103: 'CarName_plymouth fury iii',
#  104: 'CarName_plymouth satellite custom (sw)',
#  105: 'CarName_plymouth valiant',
#  106: 'CarName_porcshce panamera',
#  107: 'CarName_porsche boxter',
#  108: 'CarName_porsche cayenne',
#  109: 'CarName_porsche macan',
#  110: 'CarName_renault 12tl',
#  111: 'CarName_renault 5 gtl',
#  112: 'CarName_saab 99e',
#  113: 'CarName_saab 99gle',
#  114: 'CarName_saab 99le',
#  115: 'CarName_subaru',
#  116: 'CarName_subaru baja',
#  117: 'CarName_subaru brz',
#  118: 'CarName_subaru dl',
#  119: 'CarName_subaru r1',
#  120: 'CarName_subaru r2',
#  121: 'CarName_subaru trezia',
#  122: 'CarName_subaru tribeca',
#  123: 'CarName_toyota carina',
#  124: 'CarName_toyota celica gt',
#  125: 'CarName_toyota celica gt liftback',
#  126: 'CarName_toyota corolla',
#  127: 'CarName_toyota corolla 1200',
#  128: 'CarName_toyota corolla 1600 (sw)',
#  129: 'CarName_toyota corolla liftback',
#  130: 'CarName_toyota corolla tercel',
#  131: 'CarName_toyota corona',
#  132: 'CarName_toyota corona hardtop',
#  133: 'CarName_toyota corona liftback',
#  134: 'CarName_toyota corona mark ii',
#  135: 'CarName_toyota cressida',
#  136: 'CarName_toyota mark ii',
#  137: 'CarName_toyota starlet',
#  138: 'CarName_toyota tercel',
#  139: 'CarName_toyouta tercel',
#  140: 'CarName_vokswagen rabbit',
#  141: 'CarName_volkswagen 1131 deluxe sedan',
#  142: 'CarName_volkswagen 411 (sw)',
#  143: 'CarName_volkswagen dasher',
#  144: 'CarName_volkswagen model 111',
#  145: 'CarName_volkswagen rabbit',
#  146: 'CarName_volkswagen rabbit custom',
#  147: 'CarName_volkswagen super beetle',
#  148: 'CarName_volkswagen type 3',
#  149: 'CarName_volvo 144ea',
#  150: 'CarName_volvo 145e (sw)',
#  151: 'CarName_volvo 244dl',
#  152: 'CarName_volvo 245',
#  153: 'CarName_volvo 246',
#  154: 'CarName_volvo 264gl',
#  155: 'CarName_volvo diesel',
#  156: 'CarName_vw dasher',
#  157: 'CarName_vw rabbit',
#  158: 'symboling_-1',
#  159: 'symboling_0',
#  160: 'symboling_1',
#  161: 'symboling_2',
#  162: 'symboling_3',
#  163: 'fueltype_gas',
#  164: 'aspiration_turbo',
#  165: 'doornumber_two',
#  166: 'carbody_hardtop',
#  167: 'carbody_hatchback',
#  168: 'carbody_sedan',
#  169: 'carbody_wagon',
#  170: 'drivewheel_fwd',
#  171: 'drivewheel_rwd',
#  172: 'enginelocation_rear',
#  173: 'enginetype_dohcv',
#  174: 'enginetype_l',
#  175: 'enginetype_ohc',
#  176: 'enginetype_ohcf',
#  177: 'enginetype_ohcv',
#  178: 'enginetype_rotor',
#  179: 'cylindernumber_five',
#  180: 'cylindernumber_four',
#  181: 'cylindernumber_six',
#  182: 'cylindernumber_three',
#  183: 'cylindernumber_twelve',
#  184: 'cylindernumber_two',
#  185: 'fuelsystem_2bbl',
#  186: 'fuelsystem_4bbl',
#  187: 'fuelsystem_idi',
#  188: 'fuelsystem_mfi',
#  189: 'fuelsystem_mpfi',
#  190: 'fuelsystem_spdi',
#  191: 'fuelsystem_spfi'}

# %%
## we normalize data because data has big vlaues in decimal and it will worsen performance of our model, may overfit 
## or  we may face hardware resource high usage
# we will apply the formula normalized_train_data = (train_data - mean)/ stadrad_deviation
## firt take mean of training, then subtract mean from each value of the array slice train_data.iloc[:,0:13]
mean = train_data.iloc[:,0:13].mean(axis=0) # taking the mean of 
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /= std
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= std

# %%
mean
# Out:
# wheelbase             98.692199
# carlength            173.658156
# carwidth              65.875887
# carheight             53.648227
# curbweight          2546.787234
# enginesize           125.666667
# boreratio              3.324184
# stroke                 3.256809
# compressionratio      10.070355
# horsepower           103.702128
# peakrpm             5143.971631
# citympg               25.113475
# highwaympg            30.581560
# dtype: float64

# %%
std
# Out:
# wheelbase             6.005665
# carlength            12.320089
# carwidth              2.188604
# carheight             2.508204
# curbweight          529.769152
# enginesize           41.733451
# boreratio             0.266123
# stroke                0.296387
# compressionratio      3.868579
# horsepower           38.424275
# peakrpm             474.472458
# citympg               6.509435
# highwaympg            6.734937
# dtype: float64

# %%
mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
mean_label
# Out:
# 13379.132390070921

# %%
std_label
# Out:
# 8189.4945680106175

# %%
print(mean_label)
# Out:
# 13379.132390070921

# %%
test_label
# Out:
# 0      0.014148
# 10     0.372534
# 14     1.365880
# 15     2.122337
# 18    -1.004718
#          ...
# 192    0.056886
# 193   -0.132991
# 194   -0.053621
# 196    0.318196
# 198    0.615529
# Name: price, Length: 64, dtype: float64

# %%
train_data.shape
# Out:
# (141, 192)

# %%
#store in numpy array

# %%
test = np.array(test_data.iloc[:]).astype('float32')

# %%
train = np.array(train_data.iloc[:]).astype('float32')

# %%
test_l= np.array(test_label.astype('float32'))

# %%
train_l= np.array(train_label.astype('float32'))

# %%
train.shape[1]
# Out:
# 192

# %%
(141,192)[1]
# Out:
# 192

# %%
train.dtype
# Out:
# dtype('float32')

# %% [markdown]
# # Models section
# ```
# #WE will configure different models here according to relu, tanh , regularization, dropout etc..
# ```

# %%
# we are passing activation function as a parameter here so that we can call this function with tanh or relu while
# fitting and training the model
from keras import models
from keras import layers
def build_model(act):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= act))
  model.add(layers.Dense(32, activation= act))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               24704
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Regularized model
from keras import regularizers
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_regular('tanh').summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 10)                1930
# _________________________________________________________________
# dense_9 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_10 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %%
# dropout model
from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_drop('relu').summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                1930
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_14 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # K Fold validation section
# ## here we will use len(train)//k to make 141//4 = 36 rows for validation in each validation test and collect the validation scores for relu , tanh , regularization , and dropout

# %%
#k fold validation with relu
# 141/4
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
# 141/4
#k fold validation with tanh
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01ccdd3950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01cbb99290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01d758bb90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01cdeab170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with regularization
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01d030c680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01d32f85f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01ceff8560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01ccd90170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with dropout
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=1)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
  all_scores_drop.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.3387 - mae: 0.8193
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5041 - mae: 0.5185
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6992 - mae: 0.5297
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4423 - mae: 0.4682
# Epoch 5/100
# 106/106 [==============================] - 0s 957us/step - loss: 0.7576 - mae: 0.5450
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5304 - mae: 0.4863
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4996 - mae: 0.5146
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4124 - mae: 0.4313
# Epoch 9/100
# 106/106 [==============================] - 0s 950us/step - loss: 0.5636 - mae: 0.4791
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4390 - mae: 0.3790
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8934 - mae: 0.5648
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3451 - mae: 0.3903
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3165 - mae: 0.3617
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2450 - mae: 0.3272
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3859 - mae: 0.4296
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2317 - mae: 0.3551
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3959 - mae: 0.3616
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4106 - mae: 0.3664
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3867 - mae: 0.4150
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6396 - mae: 0.4756
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2294 - mae: 0.3205
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2368 - mae: 0.3504
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5167 - mae: 0.4584
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3284 - mae: 0.3862
# Epoch 25/100
# 106/106 [==============================] - 0s 951us/step - loss: 0.6990 - mae: 0.4633
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3193 - mae: 0.3508
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4769 - mae: 0.4176
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2397 - mae: 0.2883
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3799 - mae: 0.3739
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4323 - mae: 0.4287
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1588 - mae: 0.3141
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4327 - mae: 0.3659
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4203 - mae: 0.4049
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2982 - mae: 0.3467
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2689 - mae: 0.3481
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2128 - mae: 0.3458
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3328 - mae: 0.3645
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1729 - mae: 0.2409
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4330 - mae: 0.3653
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2848 - mae: 0.3571
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3251 - mae: 0.3204
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2176 - mae: 0.3338
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1331 - mae: 0.2817
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3432 - mae: 0.3841
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1879 - mae: 0.2948
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2673 - mae: 0.2745
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2394 - mae: 0.3064
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1585 - mae: 0.3066
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3090 - mae: 0.3243
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6126 - mae: 0.3807
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3950 - mae: 0.3402
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3824 - mae: 0.4097
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2375 - mae: 0.3146
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4308 - mae: 0.3435
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2581 - mae: 0.3052
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1272 - mae: 0.2622
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3418 - mae: 0.3464
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5856 - mae: 0.3883
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1576 - mae: 0.2701
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2748 - mae: 0.2768
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1742 - mae: 0.2642
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2980 - mae: 0.3289
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2010 - mae: 0.2457
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5335 - mae: 0.3769
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3114 - mae: 0.2987
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6099 - mae: 0.4403
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1367 - mae: 0.2298
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1466 - mae: 0.2957
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2353 - mae: 0.2594
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2316 - mae: 0.2852
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2222 - mae: 0.2826
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3098 - mae: 0.3164
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2644 - mae: 0.3073
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1449 - mae: 0.2485
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2922 - mae: 0.2836
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2264 - mae: 0.2705
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3007 - mae: 0.3321
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1628 - mae: 0.2470
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1272 - mae: 0.2518
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1023 - mae: 0.2214
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1373 - mae: 0.2759
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1550 - mae: 0.2201
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2151 - mae: 0.2535
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1729 - mae: 0.2631
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2782 - mae: 0.3166
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1207 - mae: 0.2445
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2085 - mae: 0.2511
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6235 - mae: 0.4248
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1232 - mae: 0.2215
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3005 - mae: 0.2816
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1977 - mae: 0.2582
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3432 - mae: 0.3205
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1478 - mae: 0.2786
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1174 - mae: 0.2331
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2128 - mae: 0.3039
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2175 - mae: 0.2476
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1556 - mae: 0.2692
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1786 - mae: 0.2670
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3329 - mae: 0.3187
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0852 - mae: 0.1942
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01cdc58440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3617 - mae: 0.3993
# processing fold # 1
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.1706 - mae: 0.7445
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4486 - mae: 0.5098
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3877 - mae: 0.4847
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7700 - mae: 0.6012
# Epoch 5/100
# 106/106 [==============================] - 0s 947us/step - loss: 0.9060 - mae: 0.6209
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4722 - mae: 0.4477
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4014 - mae: 0.4671
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2676 - mae: 0.3921
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6882 - mae: 0.5366
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3795 - mae: 0.4238
# Epoch 11/100
# 106/106 [==============================] - 0s 940us/step - loss: 0.4280 - mae: 0.4459
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3077 - mae: 0.3846
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4551 - mae: 0.4335
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3038 - mae: 0.3957
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3878 - mae: 0.4296
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4002 - mae: 0.4236
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3491 - mae: 0.3944
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2616 - mae: 0.3731
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3806 - mae: 0.4337
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3872 - mae: 0.4068
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2978 - mae: 0.3584
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1981 - mae: 0.2848
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2010 - mae: 0.3416
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4787 - mae: 0.4505
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1964 - mae: 0.3127
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2522 - mae: 0.3563
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2593 - mae: 0.3308
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3640 - mae: 0.4288
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2635 - mae: 0.3833
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3052 - mae: 0.3354
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1639 - mae: 0.3183
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3971 - mae: 0.4104
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3440 - mae: 0.3568
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2639 - mae: 0.3541
# Epoch 35/100
# 106/106 [==============================] - 0s 957us/step - loss: 0.3900 - mae: 0.3840
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3774 - mae: 0.3649
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5331 - mae: 0.4366
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1648 - mae: 0.2715
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1826 - mae: 0.3207
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2873 - mae: 0.3694
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1992 - mae: 0.3159
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2230 - mae: 0.2974
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1521 - mae: 0.2900
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2106 - mae: 0.3201
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2966 - mae: 0.3452
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2489 - mae: 0.2822
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3419 - mae: 0.3659
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1508 - mae: 0.2876
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1408 - mae: 0.2473
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2134 - mae: 0.3451
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1928 - mae: 0.3050
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2705 - mae: 0.3244
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2062 - mae: 0.2885
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3949 - mae: 0.3426
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2621 - mae: 0.3446
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2557 - mae: 0.2737
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2364 - mae: 0.3104
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4002 - mae: 0.3497
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3613 - mae: 0.3435
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1224 - mae: 0.2445
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1200 - mae: 0.2500
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1302 - mae: 0.2687
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1695 - mae: 0.2783
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2193 - mae: 0.2838
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3185 - mae: 0.2924
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0977 - mae: 0.2343
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2169 - mae: 0.3251
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1197 - mae: 0.2486
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2090 - mae: 0.3169
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1060 - mae: 0.2224
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3822 - mae: 0.3298
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2053 - mae: 0.2852
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1378 - mae: 0.2855
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1352 - mae: 0.2473
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2076 - mae: 0.2840
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4452 - mae: 0.3492
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3161 - mae: 0.3160
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1092 - mae: 0.2174
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0943 - mae: 0.2459
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2357 - mae: 0.3153
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2650 - mae: 0.3430
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1488 - mae: 0.2765
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2503 - mae: 0.3350
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1380 - mae: 0.2792
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2141 - mae: 0.3378
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4641 - mae: 0.3728
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1937 - mae: 0.3014
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1885 - mae: 0.3110
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4299 - mae: 0.3510
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1669 - mae: 0.2577
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0844 - mae: 0.2108
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2266 - mae: 0.3109
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1364 - mae: 0.2675
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3466 - mae: 0.3584
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2591 - mae: 0.3361
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1448 - mae: 0.2279
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1389 - mae: 0.2518
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0986 - mae: 0.2408
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1243 - mae: 0.2534
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3290 - mae: 0.3502
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01d0b84440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5563 - mae: 0.4260
# processing fold # 2
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.8828 - mae: 0.7628
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0891 - mae: 0.8202
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7820 - mae: 0.6994
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3392 - mae: 0.4781
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7188 - mae: 0.6127
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3558 - mae: 0.4503
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5262 - mae: 0.4880
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3734 - mae: 0.4024
# Epoch 9/100
# 106/106 [==============================] - 0s 949us/step - loss: 0.3011 - mae: 0.3754
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3089 - mae: 0.3917
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4844 - mae: 0.4436
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2788 - mae: 0.3593
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2501 - mae: 0.3285
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4290 - mae: 0.4465
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3145 - mae: 0.3675
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3464 - mae: 0.3587
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4387 - mae: 0.4039
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6970 - mae: 0.5009
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6291 - mae: 0.4166
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3406 - mae: 0.4028
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4250 - mae: 0.3997
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2688 - mae: 0.3654
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3298 - mae: 0.3310
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2223 - mae: 0.3168
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3997 - mae: 0.4216
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2003 - mae: 0.3285
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3909 - mae: 0.3867
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3059 - mae: 0.3446
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4737 - mae: 0.4638
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2941 - mae: 0.3396
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3097 - mae: 0.3459
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3365 - mae: 0.3302
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7774 - mae: 0.5145
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1857 - mae: 0.2880
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1667 - mae: 0.2575
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1531 - mae: 0.2584
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1282 - mae: 0.2638
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3559 - mae: 0.3421
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2881 - mae: 0.3244
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1825 - mae: 0.2777
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3305 - mae: 0.3316
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2030 - mae: 0.3137
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3063 - mae: 0.2999
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2118 - mae: 0.2807
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2729 - mae: 0.2901
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2667 - mae: 0.2904
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1889 - mae: 0.2863
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1496 - mae: 0.2608
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1876 - mae: 0.2762
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2164 - mae: 0.3133
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2929 - mae: 0.2905
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2089 - mae: 0.3208
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1560 - mae: 0.2596
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1293 - mae: 0.2226
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2730 - mae: 0.3629
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1827 - mae: 0.2833
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3380 - mae: 0.3560
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1644 - mae: 0.2747
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3482 - mae: 0.3836
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3115 - mae: 0.3150
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1929 - mae: 0.2765
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1430 - mae: 0.2460
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2976 - mae: 0.3401
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1322 - mae: 0.2447
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1657 - mae: 0.2465
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1896 - mae: 0.2705
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2392 - mae: 0.2868
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2090 - mae: 0.2808
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2202 - mae: 0.2883
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1943 - mae: 0.2764
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1624 - mae: 0.2304
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1009 - mae: 0.2046
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5310 - mae: 0.4181
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2069 - mae: 0.2810
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1512 - mae: 0.2523
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2360 - mae: 0.3513
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2474 - mae: 0.2776
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1261 - mae: 0.2475
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1989 - mae: 0.2547
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2930 - mae: 0.3624
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3437 - mae: 0.2934
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2828 - mae: 0.3453
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4095 - mae: 0.3288
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1869 - mae: 0.2787
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1715 - mae: 0.2656
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1181 - mae: 0.2512
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2411 - mae: 0.3127
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3565 - mae: 0.3574
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0982 - mae: 0.2265
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1025 - mae: 0.2330
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6497 - mae: 0.3749
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1864 - mae: 0.2934
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1062 - mae: 0.2316
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1474 - mae: 0.2781
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1583 - mae: 0.2778
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3547 - mae: 0.3382
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2678 - mae: 0.2713
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3293 - mae: 0.3195
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2244 - mae: 0.3023
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1776 - mae: 0.2540
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01cdea83b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4514 - mae: 0.4276
# processing fold # 3
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.5338 - mae: 0.8740
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9058 - mae: 0.6494
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8098 - mae: 0.5772
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7616 - mae: 0.5879
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6831 - mae: 0.5999
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5627 - mae: 0.5903
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6636 - mae: 0.5907
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4316 - mae: 0.5177
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4892 - mae: 0.5204
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4388 - mae: 0.4637
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0529 - mae: 0.6956
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4275 - mae: 0.4311
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5210 - mae: 0.5042
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5485 - mae: 0.5074
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3761 - mae: 0.4199
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3471 - mae: 0.3995
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6107 - mae: 0.5301
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4048 - mae: 0.4508
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3196 - mae: 0.4004
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3854 - mae: 0.4489
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2975 - mae: 0.4031
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5174 - mae: 0.4210
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4642 - mae: 0.4334
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3623 - mae: 0.3877
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2732 - mae: 0.3353
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7115 - mae: 0.5551
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3439 - mae: 0.3978
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1729 - mae: 0.2755
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7882 - mae: 0.5032
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2716 - mae: 0.2927
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2568 - mae: 0.3419
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4221 - mae: 0.4013
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2535 - mae: 0.3775
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4266 - mae: 0.3853
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1742 - mae: 0.2943
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2845 - mae: 0.3692
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1491 - mae: 0.2668
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5071 - mae: 0.4269
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3361 - mae: 0.3832
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6818 - mae: 0.4607
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2042 - mae: 0.3075
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3096 - mae: 0.3940
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1682 - mae: 0.2736
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3322 - mae: 0.3377
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3400 - mae: 0.3922
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2705 - mae: 0.3333
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3175 - mae: 0.3428
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1698 - mae: 0.2552
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1993 - mae: 0.3153
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2113 - mae: 0.3103
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1733 - mae: 0.3257
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1769 - mae: 0.2863
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3258 - mae: 0.3248
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1841 - mae: 0.2833
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3797 - mae: 0.3550
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1083 - mae: 0.2298
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1489 - mae: 0.2756
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1650 - mae: 0.2688
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2484 - mae: 0.3288
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4683 - mae: 0.3510
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1442 - mae: 0.2577
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2785 - mae: 0.3383
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1926 - mae: 0.2819
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1586 - mae: 0.2346
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3358 - mae: 0.3811
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2590 - mae: 0.3119
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1756 - mae: 0.2598
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3042 - mae: 0.2602
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6299 - mae: 0.4263
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1292 - mae: 0.2771
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3743 - mae: 0.3334
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2884 - mae: 0.3018
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2419 - mae: 0.3184
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2209 - mae: 0.3002
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4957 - mae: 0.4359
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2214 - mae: 0.2611
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1383 - mae: 0.2489
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2124 - mae: 0.3003
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0853 - mae: 0.2175
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2684 - mae: 0.3012
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1264 - mae: 0.2192
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2703 - mae: 0.3193
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2009 - mae: 0.3028
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2469 - mae: 0.3052
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2164 - mae: 0.2668
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5048 - mae: 0.3608
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1552 - mae: 0.2398
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1336 - mae: 0.2876
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3347 - mae: 0.3653
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3662 - mae: 0.3508
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1720 - mae: 0.2781
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2326 - mae: 0.3048
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1494 - mae: 0.2249
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2170 - mae: 0.2879
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2877 - mae: 0.3188
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3220 - mae: 0.3842
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1476 - mae: 0.2441
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2851 - mae: 0.2912
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3749 - mae: 0.3253
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4822 - mae: 0.3940
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01d32f8560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0892 - mae: 0.2202

# %% [markdown]
# # Scores
# ## here we will see  MAE mean absolute Error scores of all model which we have saved in the list during each training in above section

# %%
all_scores_relu
# Out:
# [0.322714239358902,
#  0.30507099628448486,
#  0.3883938491344452,
#  0.3106166422367096]

# %%
all_scores_tanh
# Out:
# [0.2687858045101166,
#  0.25998014211654663,
#  0.5021014213562012,
#  0.2930182218551636]

# %%
all_scores_regular
# Out:
# [0.30630752444267273,
#  0.2365373820066452,
#  0.32501187920570374,
#  0.33694061636924744]

# %%
all_scores_drop
# Out:
# [0.3992837071418762,
#  0.4260128140449524,
#  0.4276427626609802,
#  0.22017939388751984]

# %% [markdown]
# # training on the training data
# ## here we will call each model separately from Models section and train on the training data and evaluate on the test data

# %%
model_tanh = build_model('tanh')
model_tanh.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01ce7e2950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1395 - mae: 0.2668

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01d3353440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1030 - mae: 0.2479

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01cdae8cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0958 - mae: 0.1946

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f01cf0ae5f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1525 - mae: 0.2744

# %% [markdown]
# # Prediction Section
# ## here we will predict our prices of our test dataset with each model which we have trained in training section
# ## Note that here we will use the reverse process of Normalization to retrieve our values of price in thousand of dollars i.e. x = (y - mean)/ std ==>> we will calculate( y = x * std + mean) and then we will compare it with our target values

# %%
test_l
# Out:
# array([ 0.01414832,  0.3725343 ,  1.3658801 ,  2.122337  , -1.004718  ,
#        -0.7045773 , -0.5886972 , -0.97443527, -0.763189  , -0.52312535,
#        -0.05301089, -0.3704908 , -0.5449216 , -0.80397296, -0.5536523 ,
#        -0.26059392,  0.6062484 ,  1.4864004 ,  2.5404336 ,  3.367835  ,
#        -0.8779702 , -0.09159691,  0.18192424, -0.7802841 , -0.50065756,
#        -0.9622245 , -0.6813769 , -0.5409531 ,  0.01463675,  0.12453365,
#         0.46643507, -0.1806134 ,  0.2687428 ,  0.4299249 ,  0.45129374,
#        -0.07511237,  2.3382235 ,  2.200547  , -0.49870384,  0.20280465,
#         0.26019526, -0.68430746, -0.7224051 , -0.65524584, -0.98066276,
#        -0.7889537 , -0.7547636 , -0.6888255 , -0.6277716 , -0.4983375 ,
#        -0.6020069 , -0.4139611 , -0.22347318, -0.54107517,  0.28217462,
#        -0.68430746, -0.6574438 , -0.59638995, -0.01027321,  0.056886  ,
#        -0.1329914 , -0.05362143,  0.3181964 ,  0.6155285 ], dtype=float32)

# %%
def predict(model, m):
  print(f" the Actual value Price was : {test_l[m]* std_label + mean_label} " )
  return(f" the predicted Price was : {(model.predict(test[m:m+1].reshape(1,test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[18545.893]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[21607.062]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[21345.727]] '

# %%
x_drop = predict(model_drop,2)
x_drop
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[16829.023]] '

# %%
def plot_fn(mod):
  y_true = test_l* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef) 
  # poly1d_fn is now a function which takes in x and returns an estimate for y
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True' )
  plt.ylabel('Thousand Dollar Predictions' )
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f01cbbd4440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f01d029edd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f01ca9b4200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f01ca9b48c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
